# %%
import pandas as pd 
#path = "Portfolio"
data_FOLD = pd.read_csv("FOLDclose.csv")
table = pd.DataFrame(data_FOLD)
FoldClose=table.iloc[:,0];
data_FOLD = pd.read_csv("HMRZclose.csv")
table = pd.DataFrame(data_FOLD)
HmrzClose=table.iloc[:,0];
data_FOLD = pd.read_csv("MSMIclose.csv")
table = pd.DataFrame(data_FOLD)
MSMIClose=table.iloc[:,0];
data_FOLD = pd.read_csv("PKLJclose.csv")
table = pd.DataFrame(data_FOLD)
PKLJclose=table.iloc[:,0];
data_FOLD = pd.read_csv("SFKZclose.csv")
table = pd.DataFrame(data_FOLD)
SFKZclose=table.iloc[:,0];
data_FOLD = pd.read_csv("SIPAclose.csv")
table = pd.DataFrame(data_FOLD)
SIPAclose=table.iloc[:,0];
data_FOLD = pd.read_csv("PTAPclose.csv")
table = pd.DataFrame(data_FOLD)
PTAPclose=table.iloc[:,0];
data_FOLD = pd.read_csv("SGRBclose.csv")
table = pd.DataFrame(data_FOLD)
SGRBclose=table.iloc[:,0];
import matplotlib.pyplot as plt
import numpy as np
closeprices= np.zeros((4059, 8))
closeprices[4057-2898:4057,0]=FoldClose;
closeprices[4057-1410:4057,1]=HmrzClose;
closeprices[4057-2912:4057,2]=MSMIClose;
closeprices[4057-1515:4057,3]=PKLJclose;###
closeprices[4057-1475:4057,4]=PTAPclose;###
closeprices[4057-3950:4057,5]=SFKZclose;
closeprices[4057-3273:4057,6]=SGRBclose;
closeprices[0:4058,7]=SIPAclose;###

#plt.plot(closeprices[:,0]);
#plt.plot(closeprices[4057-1410:4057,1]);
#plt.plot(closeprices[4057-2912:4057,2]);
#plt.plot(closeprices[4057-1515:4057,3]);###
#plt.plot(closeprices[4057-1475:4057,4]);###
#plt.plot(closeprices[4057-3950:4057,5]);
#plt.plot(closeprices[4057-3273:4057,6]);
#plt.plot(closeprices[0:4058,7]);###

plt.plot(closeprices);

#plt.plot([1, 2, 3, 4])
plt.ylabel('close price')
plt.xlabel('Days')
#plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
#plt.plot(FoldClose)
#plt.plot(HmrzClose)
#plt.plot(MSMIClose)
#plt.plot(PKLJclose)
#plt.plot(SFKZclose)
#plt.plot(SIPAclose)
#plt.plot(SGRBclose)
#plt.plot(PTAPclose)
plt.show()

# %%
SIPAclose.shape
# Out:
# (3950,)
