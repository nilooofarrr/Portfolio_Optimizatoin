# %%
#https://keras.io/getting-started/sequential-model-guide/
import pandas as pd 
#path = "Portfolio"
data_FOLD = pd.read_csv("FOLDclose.csv")
table = pd.DataFrame(data)

#print(table[5:30])
print(table==table_FOLD)
size=table.shape
endIndex=size[0]
train_num = round(0.7*(endIndex-37))
test_num = endIndex-37 - train_num
print("total number of data= ",endIndex)
##################################Train and test files#############################
import numpy as np

train_X =np.zeros((train_num, 30, 1))
test_X =np.zeros((test_num, 30, 1))

for i in range(30, train_num):
    train_X[i-30]=table[i-30:i]
        
for i in range(train_num+30 +1, endIndex-7):    
    test_X[i-(train_num+30 +1)]=table[i-30:i]

################################generate labels####################################
import random

#train_y = np.ones((train_num,1))
#test_y = np.ones((test_num,1))
train_y = np.random.randint(0, 2, (train_num, 1))
test_y = np.random.randint(0, 2, (test_num, 1))
# print(train_y[0])
# print(test_y[0])



"""print(train_num, " Train sample")
print(test_num, " Test sample")
print("X_Trainsample[0]", train_X[0])
print("y_Trainasmple[0]", train_y[0][0])
print("X_Testsample[0]", test_X[0])
print("y_Testasmple[0]", test_y[0][0])
"""
#######################################labels#########################################
x_train =train_X
y_train =train_y
x_test =test_X
y_test =test_y

print( "x_train.shape, y_train.shape, x_test.shape,y_test.shape" )
print(x_train.shape, y_train.shape, x_test.shape,y_test.shape )
#######################################################################################
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalAveragePooling1D, MaxPooling1D

seq_length = 30

model = Sequential()
model.add(Conv1D(64, 3, activation='relu', input_shape=(seq_length, 1)))
model.add(Conv1D(64, 3, activation='relu'))
model.add(MaxPooling1D(3))
model.add(Conv1D(128, 3, activation='relu'))
model.add(Conv1D(128, 3, activation='relu'))
model.add(GlobalAveragePooling1D())
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

model.fit(x_train, y_train, batch_size=16, epochs=10)
score = model.evaluate(x_test, y_test, batch_size=16)
# Out:
#       1901
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# ...    ...
# 2868  True
# 2869  True
# 2870  True
# 2871  True
# 2872  True
# 2873  True
# 2874  True
# 2875  True
# 2876  True
# 2877  True
# 2878  True
# 2879  True
# 2880  True
# 2881  True
# 2882  True
# 2883  True
# 2884  True
# 2885  True
# 2886  True
# 2887  True
# 2888  True
# 2889  True
# 2890  True
# 2891  True
# 2892  True
# 2893  True
# 2894  True
# 2895  True
# 2896  True
# 2897  True
#
# [2898 rows x 1 columns]
# total number of data=  2898
# x_train.shape, y_train.shape, x_test.shape,y_test.shape
# (2003, 30, 1) (2003, 1) (858, 30, 1) (858, 1)
# Epoch 1/10
# ...

# %%
import pandas as pd 

"""
file = pd.read_csv("X_Test_30day.csv")
X_Test_30day = pd.DataFrame(file)
print(X_Test_30day.shape)
file = pd.read_csv("X_train_30day.csv")
X_train_30day = pd.DataFrame(file)
print(X_train_30day.shape)
"""


file = pd.read_csv("X_train_15_feature_17211.csv")
X_train_15_feature_17211 = pd.DataFrame(file)
print(X_train_15_feature_17211.shape)
file = pd.read_csv("Y_Train_daily_17211.csv")
Y_Train_daily_17211 = pd.DataFrame(file)
print(Y_Train_daily_17211.shape)
file = pd.read_csv("X_test_15_feature_4280.csv")
X_test_15_feature_4280 = pd.DataFrame(file)
print(X_test_15_feature_4280.shape)
file = pd.read_csv("X_Test_30day.csv")
X_Test_30day = pd.DataFrame(file)
print(X_Test_30day.shape)

#print(NMF15feature.head())
#size=NMF15feature.shape

#print(size)
#print(NMF15feature)
# Out:
# (17210, 15)
# (17210, 1)
# (4279, 15)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-55b9ccf0e894> in <module>()
#      20 X_test_15_feature_4280 = pd.DataFrame(file)
#      21 print(X_test_15_feature_4280.shape)
# ---> 22 file = pd.read_csv("X_Test_30day.csv")
#      23 X_Test_30day = pd.DataFrame(file)
#      24 print(X_Test_30day.shape)
#
# ...
